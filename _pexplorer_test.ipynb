# %%
import pexplorer as px
import numpy as np
import pandas as pd
import importlib

# %%
importlib.reload(px)
# Out:
# <module 'pexplorer' from 'h:\\OneDrive\\Python\\00-PACKAGES\\PANDAS\\pexplorer\\pexplorer.py'>

# %%
df = pd.read_csv(r"H:\BOOK\CSV\NYPD_Shooting_Incident_Data__Historic_.csv")

# %%
df.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME           BORO  PRECINCT  \
# 0     201575314  08/23/2019   22:10:00         QUEENS       103
# 1     205748546  11/27/2019   15:54:00          BRONX        40
# 2     193118596  02/02/2019   19:40:00      MANHATTAN        23
# 3     204192600  10/24/2019   00:52:00  STATEN ISLAND       121
# 4     201483468  08/22/2019   18:03:00          BRONX        46
#
#    JURISDICTION_CODE LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP  \
# 0                0.0           NaN                    False            NaN
# 1                0.0           NaN                    False            <18
# 2                0.0           NaN                    False          18-24
# 3                0.0     PVT HOUSE                     True          25-44
# 4                0.0           NaN                    False          25-44
#
#   PERP_SEX       PERP_RACE VIC_AGE_GROUP VIC_SEX        VIC_RACE X_COORD_CD  \
# 0      NaN             NaN         25-44       M           BLACK    1037451
# 1        M           BLACK         25-44       F           BLACK    1006789
# 2        M  WHITE HISPANIC         18-24       M  BLACK HISPANIC     999347
# 3        M           BLACK         25-44       F           BLACK     938149
# 4        M  BLACK HISPANIC         18-24       M           BLACK    1008224
#
#   Y_COORD_CD   Latitude  Longitude  \
# 0     193561  40.697805 -73.808141
# 1     237559  40.818700 -73.918571
# 2     227795  40.791916 -73.945480
# 3     171781  40.638064 -74.166108
# 4     250621  40.854547 -73.913339
#
#                                          Lon_Lat
# 0  POINT (-73.80814071699996 40.697805308000056)
# 1   POINT (-73.91857061799993 40.81869973000005)
# 2  POINT (-73.94547965999999 40.791916091000076)
# 3   POINT (-74.16610830199996 40.63806398200006)
# 4   POINT (-73.91333944399999 40.85454734900003)

# %%
px.memory_size(df)
# Out:
# '2.99 MB'

# %%
px.missing_values(df)
# Out:
# Your selected dataframe has 19 columns.
# There are 5 columns that have missing values.
# <style  type="text/css" >
# #T_6fce7_row0_col0{
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }#T_6fce7_row1_col0{
#             background-color:  #f17b1a;
#             color:  #000000;
#         }#T_6fce7_row2_col0,#T_6fce7_row3_col0{
#             background-color:  #f17c1a;
#             color:  #000000;
#         }#T_6fce7_row4_col0{
#             background-color:  #ffffe5;
#             color:  #000000;
#         }</style><table id="T_6fce7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Missing Values</th>        <th class="col_heading level0 col1" >% of Total Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6fce7_level0_row0" class="row_heading level0 row0" >LOCATION_DESC</th>
#                         <td id="T_6fce7_row0_col0" class="data row0 col0" >12361</td>
#                         <td id="T_6fce7_row0_col1" class="data row0 col1" >57.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_6fce7_level0_row1" class="row_heading level0 row1" >PERP_AGE_GROUP</th>
#                         <td id="T_6fce7_row1_col0" class="data row1 col0" >7305</td>
#                         <td id="T_6fce7_row1_col1" class="data row1 col1" >33.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_6fce7_level0_row2" class="row_heading level0 row2" >PERP_SEX</th>
#                         <td id="T_6fce7_row2_col0" class="data row2 col0" >7271</td>
#                         <td id="T_6fce7_row2_col1" class="data row2 col1" >33.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_6fce7_level0_row3" class="row_heading level0 row3" >PERP_RACE</th>
#                         <td id="T_6fce7_row3_col0" class="data row3 col0" >7271</td>
#                         <td id="T_6fce7_row3_col1" class="data row3 col1" >33.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_6fce7_level0_row4" class="row_heading level0 row4" >JURISDICTION_CODE</th>
#                         <td id="T_6fce7_row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_6fce7_row4_col1" class="data row4 col1" >0.000000</td>
#             </tr>
#     </tbody></table>

# %%
px.any_value(df, "12/01/2019")
# Out:
#      INCIDENT_KEY  OCCUR_DATE OCCUR_TIME           BORO  PRECINCT  \
# 425     205862274  12/01/2019   21:10:00       BROOKLYN        81
# 719     205862275  12/01/2019   01:07:00         QUEENS       114
# 760     205862271  12/01/2019   03:32:00  STATEN ISLAND       123
# 915     205862276  12/01/2019   22:10:00       BROOKLYN        81
#
#      JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 425                0.0                        NaN                    False
# 719                0.0                        NaN                    False
# 760                0.0                        NaN                    False
# 915                2.0  MULTI DWELL - PUBLIC HOUS                    False
#
#     PERP_AGE_GROUP PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX VIC_RACE  \
# 425          25-44        M     BLACK         25-44       M    BLACK
# 719            NaN      NaN       NaN         18-24       M    BLACK
# 760          25-44        M     WHITE         25-44       M    WHITE
# 915            NaN      NaN       NaN         25-44       M    BLACK
#
#     X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 425    1004788     190873  40.690563 -73.925943
# 719    1000151     215230  40.757427 -73.942606
# 760     935099     136277  40.540596 -74.176839
# 915    1005569     186646  40.678959 -73.923140
#
#                                            Lon_Lat
# 425   POINT (-73.92594259299995 40.69056345100006)
# 719   POINT (-73.94260579999997 40.75742705300007)
# 760   POINT (-74.17683949599996 40.54059638700005)
# 915  POINT (-73.92313972699998 40.678959457000076)

# %%
px.help()
# Out:
# ======= PandasExplorer 1.01 ========
#
# Función              Parámetros                Info
# ---------------------------------------------------------------------------------
# check_df             dataframe                 Analiza un dataframe
# col_rename           dataframe                 Cambia el nombre de las columnas

# %%
px.plot_numcat(df, "PRECINCT", "VIC_AGE_GROUP")

# %%
px.correlation(df)

# %%
px.check_df(df)
# Out:
# <style  type="text/css" >
# #T_86745_row0_col2,#T_86745_row6_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_86745_row0_col3,#T_86745_row1_col3,#T_86745_row2_col3,#T_86745_row3_col2,#T_86745_row3_col3,#T_86745_row4_col3,#T_86745_row5_col2,#T_86745_row5_col3,#T_86745_row6_col2,#T_86745_row7_col2,#T_86745_row7_col3,#T_86745_row8_col2,#T_86745_row9_col2,#T_86745_row10_col2,#T_86745_row11_col2,#T_86745_row11_col3,#T_86745_row12_col2,#T_86745_row12_col3,#T_86745_row13_col2,#T_86745_row13_col3,#T_86745_row14_col3,#T_86745_row15_col3,#T_86745_row16_col3,#T_86745_row17_col3,#T_86745_row18_col3{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_86745_row1_col2{
#             background-color:  #aad3aa;
#             color:  #000000;
#         }#T_86745_row2_col2{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_86745_row4_col2{
#             background-color:  #eaf2ea;
#             color:  #000000;
#         }#T_86745_row8_col3{
#             background-color:  #60af60;
#             color:  #000000;
#         }#T_86745_row9_col3,#T_86745_row10_col3,#T_86745_row18_col2{
#             background-color:  #61af61;
#             color:  #000000;
#         }#T_86745_row14_col2{
#             background-color:  #6eb66e;
#             color:  #000000;
#         }#T_86745_row15_col2{
#             background-color:  #6bb46b;
#             color:  #000000;
#         }#T_86745_row16_col2,#T_86745_row17_col2{
#             background-color:  #62b062;
#             color:  #000000;
#         }</style><table id="T_86745_" ><caption>RangeIndex(start=0, stop=21626, step=1)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >col. name</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >unique</th>        <th class="col_heading level0 col3" >NAN(%)</th>        <th class="col_heading level0 col4" >min</th>        <th class="col_heading level0 col5" >25%</th>        <th class="col_heading level0 col6" >50%</th>        <th class="col_heading level0 col7" >75%</th>        <th class="col_heading level0 col8" >max</th>        <th class="col_heading level0 col9" >mean</th>        <th class="col_heading level0 col10" >std</th>        <th class="col_heading level0 col11" >binary values</th>    </tr>    <tr>        <th class="index_name level0" >Num.</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86745_level0_row0" class="row_heading level0 row0" >1)</th>
#                         <td id="T_86745_row0_col0" class="data row0 col0" >INCIDENT_KEY</td>
#                         <td id="T_86745_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_86745_row0_col2" class="data row0 col2" >17031</td>
#                         <td id="T_86745_row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_86745_row0_col4" class="data row0 col4" >9953245</td>
#                         <td id="T_86745_row0_col5" class="data row0 col5" >51709091.250000</td>
#                         <td id="T_86745_row0_col6" class="data row0 col6" >80495595.500000</td>
#                         <td id="T_86745_row0_col7" class="data row0 col7" >140791303.750000</td>
#                         <td id="T_86745_row0_col8" class="data row0 col8" >206891917</td>
#                         <td id="T_86745_row0_col9" class="data row0 col9" >92011669.577222</td>
#                         <td id="T_86745_row0_col10" class="data row0 col10" >52530697.410443</td>
#                         <td id="T_86745_row0_col11" class="data row0 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_86745_level0_row1" class="row_heading level0 row1" >2)</th>
#                         <td id="T_86745_row1_col0" class="data row1 col0" >OCCUR_DATE</td>
#                         <td id="T_86745_row1_col1" class="data row1 col1" >object</td>
#                         <td id="T_86745_row1_col2" class="data row1 col2" >4711</td>
#                         <td id="T_86745_row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_86745_row1_col4" class="data row1 col4" >-</td>
#                         <td id="T_86745_row1_col5" class="data row1 col5" >-</td>
#                         <td id="T_86745_row1_col6" class="data row1 col6" >-</td>
#                         <td id="T_86745_row1_col7" class="data row1 col7" >-</td>
#                         <td id="T_86745_row1_col8" class="data row1 col8" >-</td>
#                         <td id="T_86745_row1_col9" class="data row1 col9" >-</td>
#                         <td id="T_86745_row1_col10" class="data row1 col10" >-</td>
#                         <td id="T_86745_row1_col11" class="data row1 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_86745_level0_row2" class="row_heading level0 row2" >3)</th>
#                         <td id="T_86745_row2_col0" class="data row2 col0" >OCCUR_TIME</td>
#                         <td id="T_86745_row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_86745_row2_col2" class="data row2 col2" >1583</td>
#                         <td id="T_86745_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_86745_row2_col4" class="data row2 col4" >-</td>
#                         <td id="T_86745_row2_col5" class="data row2 col5" >-</td>
#                         <td id="T_86745_row2_col6" class="data row2 col6" >-</td>
#                         <td id="T_86745_row2_col7" class="data row2 col7" >-</td>
#                         <td id="T_86745_row2_col8" class="data row2 col8" >-</td>
#                         <td id="T_86745_row2_col9" class="data row2 col9" >-</td>
#                         <td id="T_86745_row2_col10" class="data row2 col10" >-</td>
#                         <td id="T_86745_row2_col11" class="data row2 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_86745_level0_row3" class="row_heading level0 row3" >4)</th>
#                         <td id="T_86745_row3_col0" class="data row3 col0" >BORO</td>
#                         <td id="T_86745_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_86745_row3_col2" class="data row3 col2" >5</td>
#                         <td id="T_86745_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_86745_row3_col4" class="data row3 col4" >-</td>
#                         <td id="T_86745_row3_col5" class="data row3 col5" >-</td>
#                         <td id="T_86745_row3_col6" class="data row3 col6" >-</td>
#                         <td id="T_86745_row3_col7" class="data row3 col7" >-</td>
#                         <td id="T_86745_row3_col8" class="data row3 col8" >-</td>
#                         <td id="T_86745_row3_col9" class="data row3 col9" >-</td>
#                         <td id="T_86745_row3_col10" class="data row3 col10" >-</td>
#                         <td id="T_86745_row3_col11" class="data row3 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_86745_level0_row4" class="row_heading level0 row4" >5)</th>
#                         <td id="T_86745_row4_col0" class="data row4 col0" >PRECINCT</td>
#                         <td id="T_86745_row4_col1" class="data row4 col1" >int64</td>
#                         <td id="T_86745_row4_col2" class="data row4 col2" >76</td>
#                         <td id="T_86745_row4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_86745_row4_col4" class="data

# %%
df = px.clean_nan(df, 0.4)
# Out:
# Se eliminaron las sig. columnas:
# -------------------------
# LOCATION_DESC

# %%
df = px.col_rename(df)

# %%
df.columns
# Out:
# Index(['incident_key', 'occur_date', 'occur_time', 'boro', 'precinct',
#        'jurisdiction_code', 'statistical_murder_flag', 'perp_age_group',
#        'perp_sex', 'perp_race', 'vic_age_group', 'vic_sex', 'vic_race',
#        'x_coord_cd', 'y_coord_cd', 'latitude', 'longitude', 'lon_lat'],
#       dtype='object')

# %%
px.check_cat(df)
# Out:
# Las columnas recomendadas:
# --------------------------
# boro(5)
# jurisdiction_code(4)
# perp_age_group(10)
# perp_sex(4)
# perp_race(8)
# vic_age_group(6)
# vic_sex(3)
# vic_race(7)

# %%
df = px.make_cat(df)
# Out:
# Las columnas convertidas:
# -------------------------
# boro (5)
# jurisdiction_code (4)
# perp_age_group (9)
# perp_sex (4)
# perp_race (7)
# vic_age_group (6)
# vic_sex (3)
# vic_race (7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21626 entries, 0 to 21625
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   incident_key             21626 non-null  int64
#  1   occur_date               21626 non-null  object
#  2   occur_time               21626 non-null  object
#  3   boro                     21626 non-null  category
#  4   precinct                 21626 non-null  int64
#  5   jurisdiction_code        21626 non-null  category
#  6   statistical_murder_flag  21626 non-null  bool
#  7   perp_age_group           21626 non-null  category
#  8   perp_sex                 21626 non-null  category
#  9   perp_race                21626 non-null  category
#  10  vic_age_group            21626 non-null  category
#  11  vic_sex                  21626 non-null  category
#  12  vic_race                 21626 non-null  category
#  13  x_coord_cd               21626 non-null  object
#  14  y_coord_cd               21626 non-null  object
#  15  latitude                 21626 non-null  float64
#  16  longitude                21626 non-null  float64
#  17  lon_lat                  21626 non-null  object
# dtypes: bool(1), category(8), float64(2), int64(2), object(5)
# memory usage: 1.7+ MB

# %%
df_num, df_cat = px.split_values(df)

# %%
px.grid_plot(df)

# %%
px.help()
# Out:
# ======= PandasExplorer 1.01 ========
#
# Función              Parámetros                Info
# ---------------------------------------------------------------------------------
# check_df             dataframe                 Analiza un dataframe
