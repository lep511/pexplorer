# %%
import pexplorer as px
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"H:\BOOK\CSV\NYPD_Shooting_Incident_Data__Historic_.csv")

# %%
px.correlation(df)
# Out:
# <style  type="text/css" >
# #T_5be5b_row0_col0,#T_5be5b_row1_col1,#T_5be5b_row2_col2,#T_5be5b_row3_col3,#T_5be5b_row4_col4,#T_5be5b_row5_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_5be5b_row0_col1{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_5be5b_row0_col2{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_5be5b_row0_col3,#T_5be5b_row4_col3{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_5be5b_row0_col4{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_5be5b_row0_col5{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_5be5b_row1_col0{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_5be5b_row1_col2,#T_5be5b_row4_col0{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_5be5b_row1_col3{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_5be5b_row1_col4,#T_5be5b_row2_col3,#T_5be5b_row2_col5,#T_5be5b_row3_col0,#T_5be5b_row4_col1,#T_5be5b_row5_col0,#T_5be5b_row5_col2{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_5be5b_row1_col5{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_5be5b_row2_col0{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_5be5b_row2_col1{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_5be5b_row2_col4{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_5be5b_row3_col1{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_5be5b_row3_col2,#T_5be5b_row5_col3{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_5be5b_row3_col4{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_5be5b_row3_col5{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_5be5b_row4_col2{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_5be5b_row4_col5{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_5be5b_row5_col1{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_5be5b_row5_col4{
#             background-color:  #79abd0;
#             color:  #000000;
#         }</style><table id="T_5be5b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >INCIDENT_KEY</th>        <th class="col_heading level0 col1" >PRECINCT</th>        <th class="col_heading level0 col2" >JURISDICTION_CODE</th>        <th class="col_heading level0 col3" >STATISTICAL_MURDER_FLAG</th>        <th class="col_heading level0 col4" >Latitude</th>        <th class="col_heading level0 col5" >Longitude</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5be5b_level0_row0" class="row_heading level0 row0" >INCIDENT_KEY</th>
#                         <td id="T_5be5b_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_5be5b_row0_col1" class="data row0 col1" >0.001186</td>
#                         <td id="T_5be5b_row0_col2" class="data row0 col2" >0.039118</td>
#                         <td id="T_5be5b_row0_col3" class="data row0 col3" >-0.011293</td>
#                         <td id="T_5be5b_row0_col4" class="data row0 col4" >0.009756</td>
#                         <td id="T_5be5b_row0_col5" class="data row0 col5" >-0.007798</td>
#             </tr>
#             <tr>
#                         <th id="T_5be5b_level0_row1" class="row_heading level0 row1" >PRECINCT</th>
#                         <td id="T_5be5b_row1_col0" class="data row1 col0" >0.001186</td>
#                         <td id="T_5be5b_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_5be5b_row1_col2" class="data row1 col2" >-0.061853</td>
#                         <td id="T_5be5b_row1_col3" class="data row1 col3" >0.015602</td>
#                         <td id="T_5be5b_row1_col4" class="data row1 col4" >-0.651051</td>
#                         <td id="T_5be5b_row1_col5" class="data row1 col5" >0.175072</td>
#             </tr>
#             <tr>
#                         <th id="T_5be5b_level0_row2" class="row_heading level0 row2" >JURISDICTION_CODE</th>
#                         <td id="T_5be5b_row2_col0" class="data row2 col0" >0.039118</td>
#                         <td id="T_5be5b_row2_col1" class="data row2 col1" >-0.061853</td>
#                         <td id="T_5be5b_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_5be5b_row2_col3" class="data row2 col3" >-0.041350</td>
#                         <td id="T_5be5b_row2_col4" class="data row2 col4" >-0.023243</td>
#                         <td id="T_5be5b_row2_col5" class="data row2 col5" >-0.087191</td>
#             </tr>
#             <tr>
#                         <th id="T_5be5b_level0_row3" class="row_heading level0 row3" >STATISTICAL_MURDER_FLAG</th>
#                         <td id="T_5be5b_row3_col0" class="data row3 col0" >-0.011293</td>
#                         <td id="T_5be5b_row3_col1" class="data row3 col1" >0.015602</td>
#                         <td id="T_5be5b_row3_col2" class="data row3 col2" >-0.041350</td>
#                         <td id="T_5be5b_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_5be5b_row3_col4" class="data row3 col4" >-0.011255</td>
#                         <td id="T_5be5b_row3_col5" class="data row3 col5" >0.001971</td>
#             </tr>
#             <tr>
#                         <th id="T_5be5b_level0_row4" class="row_heading level0 row4" >Latitude</th>
#                         <td id="T_5be5b_row4_col0" class="data row4 col0" >0.009756</td>
#                         <td id="T_5be5b_row4_col1" class="data row4 col1" >-0.651051</td>
#                         <td id="T_5be5b_row4_col2" class="data row4 col2" >-0.023243</td>
#                         <td id="T_5be5b_row4_col3" class="data row4 col3" >-0.011255</td>
#                         <td id="T_5be5b_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_5be5b_row4_col5" class="data row4 col5" >0.151203</td>
#             </tr>
#             <tr>
#                         <th id="T_5be5b_level0_row5" class="row_heading level0 row5" >Longitude</th>
#                         <td id="T_5be5b_row5_col0" class="data row5 col0" >-0.007798</td>
#                         <td id="T_5be5b_row5_col1" class="data row5 col1" >0.175072</td>
#                         <td id="T_5be5b_row5_col2" class="data row5 col2" >-0.087191</td>
#                         <td id="T_5be5b_row5_col3" class="data row5 col3" >0.001971</td>
#                         <td id="T_5be5b_row5_col4" class="data row5 col4" >0.151203</td>
#                         <td id="T_5be5b_row5_col5" class="data row5 col5" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
px.check_df(df)
# Out:
# <style  type="text/css" >
# #T_0dada_row0_col2,#T_0dada_row6_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_0dada_row0_col3,#T_0dada_row1_col3,#T_0dada_row2_col3,#T_0dada_row3_col2,#T_0dada_row3_col3,#T_0dada_row4_col3,#T_0dada_row5_col2,#T_0dada_row5_col3,#T_0dada_row6_col2,#T_0dada_row7_col2,#T_0dada_row7_col3,#T_0dada_row8_col2,#T_0dada_row9_col2,#T_0dada_row10_col2,#T_0dada_row11_col2,#T_0dada_row11_col3,#T_0dada_row12_col2,#T_0dada_row12_col3,#T_0dada_row13_col2,#T_0dada_row13_col3,#T_0dada_row14_col3,#T_0dada_row15_col3,#T_0dada_row16_col3,#T_0dada_row17_col3,#T_0dada_row18_col3{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_0dada_row1_col2{
#             background-color:  #aad3aa;
#             color:  #000000;
#         }#T_0dada_row2_col2{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_0dada_row4_col2{
#             background-color:  #eaf2ea;
#             color:  #000000;
#         }#T_0dada_row8_col3{
#             background-color:  #60af60;
#             color:  #000000;
#         }#T_0dada_row9_col3,#T_0dada_row10_col3,#T_0dada_row18_col2{
#             background-color:  #61af61;
#             color:  #000000;
#         }#T_0dada_row14_col2{
#             background-color:  #6eb66e;
#             color:  #000000;
#         }#T_0dada_row15_col2{
#             background-color:  #6bb46b;
#             color:  #000000;
#         }#T_0dada_row16_col2,#T_0dada_row17_col2{
#             background-color:  #62b062;
#             color:  #000000;
#         }</style><table id="T_0dada_" ><caption>RangeIndex(start=0, stop=21626, step=1)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >col. name</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >unique</th>        <th class="col_heading level0 col3" >NAN(%)</th>        <th class="col_heading level0 col4" >min</th>        <th class="col_heading level0 col5" >25%</th>        <th class="col_heading level0 col6" >50%</th>        <th class="col_heading level0 col7" >75%</th>        <th class="col_heading level0 col8" >max</th>        <th class="col_heading level0 col9" >mean</th>        <th class="col_heading level0 col10" >std</th>        <th class="col_heading level0 col11" >binary values</th>    </tr>    <tr>        <th class="index_name level0" >Num.</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0dada_level0_row0" class="row_heading level0 row0" >1)</th>
#                         <td id="T_0dada_row0_col0" class="data row0 col0" >INCIDENT_KEY</td>
#                         <td id="T_0dada_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_0dada_row0_col2" class="data row0 col2" >17031</td>
#                         <td id="T_0dada_row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_0dada_row0_col4" class="data row0 col4" >9953245</td>
#                         <td id="T_0dada_row0_col5" class="data row0 col5" >51709091.250000</td>
#                         <td id="T_0dada_row0_col6" class="data row0 col6" >80495595.500000</td>
#                         <td id="T_0dada_row0_col7" class="data row0 col7" >140791303.750000</td>
#                         <td id="T_0dada_row0_col8" class="data row0 col8" >206891917</td>
#                         <td id="T_0dada_row0_col9" class="data row0 col9" >92011669.577222</td>
#                         <td id="T_0dada_row0_col10" class="data row0 col10" >52530697.410443</td>
#                         <td id="T_0dada_row0_col11" class="data row0 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_0dada_level0_row1" class="row_heading level0 row1" >2)</th>
#                         <td id="T_0dada_row1_col0" class="data row1 col0" >OCCUR_DATE</td>
#                         <td id="T_0dada_row1_col1" class="data row1 col1" >object</td>
#                         <td id="T_0dada_row1_col2" class="data row1 col2" >4711</td>
#                         <td id="T_0dada_row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_0dada_row1_col4" class="data row1 col4" >-</td>
#                         <td id="T_0dada_row1_col5" class="data row1 col5" >-</td>
#                         <td id="T_0dada_row1_col6" class="data row1 col6" >-</td>
#                         <td id="T_0dada_row1_col7" class="data row1 col7" >-</td>
#                         <td id="T_0dada_row1_col8" class="data row1 col8" >-</td>
#                         <td id="T_0dada_row1_col9" class="data row1 col9" >-</td>
#                         <td id="T_0dada_row1_col10" class="data row1 col10" >-</td>
#                         <td id="T_0dada_row1_col11" class="data row1 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_0dada_level0_row2" class="row_heading level0 row2" >3)</th>
#                         <td id="T_0dada_row2_col0" class="data row2 col0" >OCCUR_TIME</td>
#                         <td id="T_0dada_row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_0dada_row2_col2" class="data row2 col2" >1583</td>
#                         <td id="T_0dada_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_0dada_row2_col4" class="data row2 col4" >-</td>
#                         <td id="T_0dada_row2_col5" class="data row2 col5" >-</td>
#                         <td id="T_0dada_row2_col6" class="data row2 col6" >-</td>
#                         <td id="T_0dada_row2_col7" class="data row2 col7" >-</td>
#                         <td id="T_0dada_row2_col8" class="data row2 col8" >-</td>
#                         <td id="T_0dada_row2_col9" class="data row2 col9" >-</td>
#                         <td id="T_0dada_row2_col10" class="data row2 col10" >-</td>
#                         <td id="T_0dada_row2_col11" class="data row2 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_0dada_level0_row3" class="row_heading level0 row3" >4)</th>
#                         <td id="T_0dada_row3_col0" class="data row3 col0" >BORO</td>
#                         <td id="T_0dada_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_0dada_row3_col2" class="data row3 col2" >5</td>
#                         <td id="T_0dada_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_0dada_row3_col4" class="data row3 col4" >-</td>
#                         <td id="T_0dada_row3_col5" class="data row3 col5" >-</td>
#                         <td id="T_0dada_row3_col6" class="data row3 col6" >-</td>
#                         <td id="T_0dada_row3_col7" class="data row3 col7" >-</td>
#                         <td id="T_0dada_row3_col8" class="data row3 col8" >-</td>
#                         <td id="T_0dada_row3_col9" class="data row3 col9" >-</td>
#                         <td id="T_0dada_row3_col10" class="data row3 col10" >-</td>
#                         <td id="T_0dada_row3_col11" class="data row3 col11" >-</td>
#             </tr>
#             <tr>
#                         <th id="T_0dada_level0_row4" class="row_heading level0 row4" >5)</th>
#                         <td id="T_0dada_row4_col0" class="data row4 col0" >PRECINCT</td>
#                         <td id="T_0dada_row4_col1" class="data row4 col1" >int64</td>
#                         <td id="T_0dada_row4_col2" class="data row4 col2" >76</td>
#                         <td id="T_0dada_row4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_0dada_row4_col4" class="data

# %%
df = px.clean_nan(df, 0.4)
# Out:
# Se eliminaron las sig. columnas:
# -------------------------
# LOCATION_DESC

# %%
df = px.col_rename(df)

# %%
df.columns
# Out:
# Index(['incident_key', 'occur_date', 'occur_time', 'boro', 'precinct',
#        'jurisdiction_code', 'statistical_murder_flag', 'perp_age_group',
#        'perp_sex', 'perp_race', 'vic_age_group', 'vic_sex', 'vic_race',
#        'x_coord_cd', 'y_coord_cd', 'latitude', 'longitude', 'lon_lat'],
#       dtype='object')

# %%
px.check_cat(df)
# Out:
# Las columnas recomendadas:
# --------------------------
# boro(5)
# jurisdiction_code(4)
# perp_age_group(10)
# perp_sex(4)
# perp_race(8)
# vic_age_group(6)
# vic_sex(3)
# vic_race(7)

# %%
df = px.make_cat(df)
# Out:
# Las columnas convertidas:
# -------------------------
# boro (5)
# jurisdiction_code (4)
# perp_age_group (9)
# perp_sex (4)
# perp_race (7)
# vic_age_group (6)
# vic_sex (3)
# vic_race (7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21626 entries, 0 to 21625
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   incident_key             21626 non-null  int64
#  1   occur_date               21626 non-null  object
#  2   occur_time               21626 non-null  object
#  3   boro                     21626 non-null  category
#  4   precinct                 21626 non-null  int64
#  5   jurisdiction_code        21626 non-null  category
#  6   statistical_murder_flag  21626 non-null  bool
#  7   perp_age_group           21626 non-null  category
#  8   perp_sex                 21626 non-null  category
#  9   perp_race                21626 non-null  category
#  10  vic_age_group            21626 non-null  category
#  11  vic_sex                  21626 non-null  category
#  12  vic_race                 21626 non-null  category
#  13  x_coord_cd               21626 non-null  object
#  14  y_coord_cd               21626 non-null  object
#  15  latitude                 21626 non-null  float64
#  16  longitude                21626 non-null  float64
#  17  lon_lat                  21626 non-null  object
# dtypes: bool(1), category(8), float64(2), int64(2), object(5)
# memory usage: 1.7+ MB

# %%
df_num, df_cat = px.split_values(df)

# %%
px.grid_plot(df)
