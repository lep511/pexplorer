# %%
import pexplorer as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
import importlib
importlib.reload(px)
# Out:
# <module 'pexplorer' from 'c:\\Users\\esteb\\Documents\\GitHub\\pexplorer\\pexplorer.py'>

# %%
df = pd.read_csv("data_sample\Tree_Species.csv")

# %%
df.head()
# Out:
#              X             Y  OBJECTID  SiteID  Address     Street   OnStreet  \
# 0  473049.2450  5.362325e+06         1     189      100  DALLAS RD  DALLAS RD
# 1  473054.9248  5.362394e+06         3     222      100  DALLAS RD  DALLAS RD
# 2  473025.5742  5.362326e+06         4     258      100  DALLAS RD  DALLAS RD
# 3  472875.7893  5.362401e+06         5     281      100  DALLAS RD  DALLAS RD
# 4  472991.8027  5.362416e+06         6     315      100  DALLAS RD  DALLAS RD
#
#   FromStreet    ToStreet SideOfParcel  ...  DiameterAtBreastHeight  GrowSpace  \
# 0    COOK ST  DOUGLAS ST          NaN  ...                    81.0  Shrub bed
# 1    COOK ST  DOUGLAS ST          NaN  ...                    48.0       Turf
# 2    COOK ST  DOUGLAS ST          NaN  ...                    55.0       Turf
# 3    COOK ST  DOUGLAS ST          NaN  ...                    40.0  Shrub bed
# 4    COOK ST  DOUGLAS ST          NaN  ...                    60.0  Shrub bed
#
# ...

# %%
px.col_rename(df)
# Out:
# {'X': 'x',
#  'Y': 'y',
#  'OBJECTID': 'objectid',
#  'SiteID': 'site',
#  'Address': 'address',
#  'Street': 'street',
#  'OnStreet': 'on_street',
#  'FromStreet': 'from_street',
#  'ToStreet': 'to_street',
#  'SideOfParcel': 'side_of_parcel',
#  'Site': 'site',
#  'Species': 'species',
#  'DiameterAtBreastHeight': 'diameter_at_breast_height',
#  'GrowSpace': 'grow_space',
#  'Trunks': 'trunks',
#  'Height': 'height',
#  'Width': 'width',
#  'TreeCategory': 'tree_category',
#  'Area': 'area',
#  'Parks': 'parks',
#  'BotanicalName': 'botanical_name',
#  'CommonName': 'common_name'}

# %%
dm = "DdfffdSDDSDS"
dm.isupper()
# Out:
# False

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
px.missing_values(df)
# Out:
# Your selected dataframe has 12 columns.
# There are 3 columns that have missing values.
# <style type="text/css">
# #T_d9787_row0_col0 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_d9787_row1_col0 {
#   background-color: #fee28e;
#   color: #000000;
# }
# #T_d9787_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_d9787_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Missing Values</th>
#       <th class="col_heading level0 col1" >% of Total Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9787_level0_row0" class="row_heading level0 row0" >Cabin</th>
#       <td id="T_d9787_row0_col0" class="data row0 col0" >687</td>
#       <td id="T_d9787_row0_col1" class="data row0 col1" >0.770000</td>
#     </tr>
#     <tr>
#       <th id="T_d9787_level0_row1" class="row_heading level0 row1" >Age</th>
# ...

# %%
px.correlation_col(df, "Survived")
# Out:
# Column Survived is not found in the dataframe.

# %%
px.missing_graph(df)

# %%
px.plot_distribution(df, "volume")

# %%
px.info_num(df)
# Out:
#   Count  Minimum  Maximum  Average  Median  Std. Dev.  Variance  Skewness  \
#   891.0     1.00   891.00   446.00  446.00     257.35  66231.00      0.00
#   891.0     0.00     1.00     0.38    0.00       0.49      0.24      0.48
#   891.0     1.00     3.00     2.31    3.00       0.84      0.70     -0.63
#   714.0     0.42    80.00    29.70   28.00      14.53    211.02      0.39
#   891.0     0.00     8.00     0.52    0.00       1.10      1.22      3.70
#   891.0     0.00     6.00     0.38    0.00       0.81      0.65      2.75
#   891.0     0.00   512.33    32.20   14.45      49.69   2469.44      4.79
#
#   Kurtosis
#      -1.20
#      -1.78
#      -1.28
#       0.18
#      17.88
#       9.78
#      33.40

# %%
df = df["Date"].to_frame()

# %%
px.plot_distribution_col(df, "Age")
# Out:
# ==== Age ====
# Count: 714
# Minimum: 0.42
# Maximum: 80.0
# Average: 29.7
# Median: 28.0
# Standard Deviation (dispersion): 14.53
# Variance (spread out): 211.02
# Skewness (distortion or asymmetry): 0.39
# Kurtosis (peakedness of a distribution): 0.18

# %%
np.quantile(df.age.dropna(), 0.25)
# Out:
# 20.125

# %%
df.columns = pe.col_rename(df)

# %%
pe.glimpse(df)
# Out:
# Rows: 2,148
# Columns: 7
#              dtype                                      sample values
# date        object  [2004-08-19, 2004-08-20, 2004-08-23, 2004-08-2...
# open       float64  [100.0, 101.01, 110.75, 111.24, 104.96, 104.95...
# high       float64  [104.06, 109.08, 113.48, 111.6, 108.0, 107.95,...
# low        float64  [95.96, 100.5, 109.05, 103.57, 103.88, 104.66,...
# close      float64  [100.34, 108.31, 109.4, 104.87, 106.0, 107.91,...
# volume       int64  [22351900, 11428600, 9137200, 7631300, 4598900...
# adj_close  float64  [100.34, 108.31, 109.4, 104.87, 106.0, 107.91,...

# %%
pe.missing_values(df)
# Out:
# Your selected dataframe has 7 columns.
# There are 0 columns that have missing values.

# %%
pe.plot_numcat(df, "open", "date")

# %%
pe.correlation(df)

# %%
df = pe.clean_nan(df, 0.4)
# Out:
# No se eliminó ninguna columna.

# %%
df = pe.col_rename(df)

# %%
pe.check_cat(df)
# Out:
# No hay columnas recomendadas para convertir.

# %%
df = pe.make_cat(df)

# %%
df_num, df_cat = pe.split_values(df)

# %%
pe.grid_plot(df)
# Out:
#  guarde un momento...

# %%
importlib.reload(pe)
# Out:
# <module 'pexplorer' from 'h:\\MEGA\\Python\\00-PACKAGES\\PANDAS\\pexplorer\\pexplorer\\pexplorer.py'>

# %%
pe.outliers(df)
# Out:
# === Grubbs' test ===
# volume
#
#  === Tukey's method  ===
# volume [19840000, 22236800, 21162500, 20804100, 22551300, 23287300, 19833100, 21388300, 25782800, 35191700, 38562200, 20917400, 22741400, 22351900, 22307100, 25814300, 29043100, 20883100, 21936800, 41116700, 39437600, 25700900, 32764200, 19717800, 21315500, 23386800, 24323000, 36521400, 21024700, 32799300, 20485700, 27122500, 22525900, 22066000, 19789400, 33205100, 22892400, 21495800, 36891900]
#
#
#  === Z-Score method  ===
# volume [19840000, 22236800, 21162500, 20804100, 22551300, 23287300, 19833100, 21388300, 25782800, 35191700, 38562200, 20917400, 22741400, 22351900, 22307100, 25814300, 29043100, 20883100, 21936800, 41116700, 39437600, 25700900, 19325600, 32764200, 19717800, 18982700, 21315500, 19027500, 23386800, 24323000, 36521400, 21024700, 32799300, 20485700, 27122500, 22525900, 22066000, 19036500, 19789400, 33205100, 22892400, 21495800, 36891900]
# ['volume']

# %%
pe.outliers_graph(df)

# %%
pe.plot_distribution(df, norm=False, exclude="Volume")
