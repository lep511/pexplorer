# %%
import pexplorer as px
import pandas as pd

# %%
df = pd.read_csv("cereal.csv")

# %%
px.check_df(df)
# Out:
# <style  type="text/css" >
# #T_06ffd_row0_col2,#T_06ffd_row15_col2{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_06ffd_row0_col3,#T_06ffd_row1_col3,#T_06ffd_row2_col2,#T_06ffd_row2_col3,#T_06ffd_row3_col3,#T_06ffd_row4_col3,#T_06ffd_row5_col3,#T_06ffd_row6_col3,#T_06ffd_row7_col3,#T_06ffd_row8_col3,#T_06ffd_row9_col3,#T_06ffd_row10_col3,#T_06ffd_row11_col3,#T_06ffd_row12_col3,#T_06ffd_row13_col3,#T_06ffd_row14_col3,#T_06ffd_row15_col3{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_06ffd_row1_col2,#T_06ffd_row13_col2{
#             background-color:  #dbebdb;
#             color:  #000000;
#         }#T_06ffd_row3_col2{
#             background-color:  #cfe5cf;
#             color:  #000000;
#         }#T_06ffd_row4_col2{
#             background-color:  #dfeddf;
#             color:  #000000;
#         }#T_06ffd_row5_col2{
#             background-color:  #e1eee1;
#             color:  #000000;
# ...
