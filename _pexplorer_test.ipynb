# %%
import pexplorer as px
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"H:\BOOK\CSV\Forestry_Planting_Spaces.csv", nrows=5000)

# %%
px.check_df(df)
# Out:
# <style  type="text/css" >
# #T_f69f6_row0_col2,#T_f69f6_row13_col3,#T_f69f6_row21_col2,#T_f69f6_row22_col2,#T_f69f6_row34_col2{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_f69f6_row0_col3,#T_f69f6_row1_col2,#T_f69f6_row1_col3,#T_f69f6_row4_col2,#T_f69f6_row4_col3,#T_f69f6_row6_col2,#T_f69f6_row6_col3,#T_f69f6_row7_col2,#T_f69f6_row7_col3,#T_f69f6_row12_col3,#T_f69f6_row13_col2,#T_f69f6_row14_col3,#T_f69f6_row15_col3,#T_f69f6_row16_col3,#T_f69f6_row17_col3,#T_f69f6_row18_col2,#T_f69f6_row18_col3,#T_f69f6_row20_col2,#T_f69f6_row20_col3,#T_f69f6_row21_col3,#T_f69f6_row22_col3,#T_f69f6_row23_col3,#T_f69f6_row25_col2,#T_f69f6_row26_col2,#T_f69f6_row26_col3,#T_f69f6_row27_col2,#T_f69f6_row34_col3{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_f69f6_row2_col2{
#             background-color:  #76ba76;
#             color:  #000000;
#         }#T_f69f6_row2_col3{
#             background-color:  #b0d6b0;
# ...

# %%
px.
# Out:
# Index(['OBJECTID', 'Borough', 'Number', 'Street', 'PSSite',
#        'PlantingSpaceOnStreet', 'Width', 'Length', 'ParkName', 'ParkZone',
#        'CrossStreet1', 'CrossStreet2', 'CommunityBoard', 'SanitationZone',
#        'Postcode', 'Council District', 'StateSenate', 'StateAssembly',
#        'Congressional', 'PhysicalID', 'PSStatus', 'Geometry', 'GlobalID',
#        'CreatedDate', 'UpdatedDate', 'Jurisdiction', 'OverheadUtilities',
#        'TreeGuard', 'Latitude', 'Longitude', 'Census Tract', 'BIN', 'BBL',
#        'NTA', 'Location'],
#       dtype='object')

# %%
np.nanpercentile(df["OBJECTID"], 50)
# Out:
# 4960567.0

# %%
df = px.col_rename(df)

# %%
df
# Out:
#       objectid        borough number           street  pssite  \
# 0       283721       Brooklyn     62     RIVER STREET  Street
# 1      7669836         Queens    NaN              NaN    Park
# 2      7123408       Brooklyn    NaN              NaN    Park
# 3      4984076         Queens  22-23           149 ST  Street
# 4      7187037         Queens    NaN              NaN    Park
# ...        ...            ...    ...              ...     ...
# 4995   7673089      Manhattan    NaN              NaN    Park
# 4996    719066          Bronx    522   TIFFANY STREET  Street
# 4997   4939496       Brooklyn   2196    EAST 3 STREET  Street
# 4998   6913013  Staten Island     31   TALLMAN STREET  Street
# 4999   2335765      Manhattan    362  WEST  53 STREET  Street
#
#      plantingspaceonstreet  width  length             parkname   parkzone  \
# 0                      NaN    0.0     0.0                  NaN        NaN
# ...
