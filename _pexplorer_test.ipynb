# %%
import pexplorer as px
import numpy as np
import pandas as pd

# %%
import importlib
importlib.reload(px)
# Out:
# <module 'pexplorer' from 'c:\\Users\\esteb\\Documents\\GitHub\\pexplorer\\pexplorer.py'>

# %%
df = pd.read_csv("cereal.csv")

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
px.memory_size(df)
# Out:
# '1.67 MB'

# %%
px.check_df(df)
# Out:
# <style  type="text/css" >
# #T_a716c_row0_col2{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_a716c_row0_col3,#T_a716c_row1_col3,#T_a716c_row2_col3,#T_a716c_row3_col2,#T_a716c_row3_col3,#T_a716c_row4_col3,#T_a716c_row5_col2,#T_a716c_row5_col3,#T_a716c_row6_col2,#T_a716c_row6_col3,#T_a716c_row7_col2,#T_a716c_row7_col3,#T_a716c_row8_col2,#T_a716c_row8_col3,#T_a716c_row9_col2,#T_a716c_row9_col3,#T_a716c_row10_col2,#T_a716c_row10_col3,#T_a716c_row11_col2,#T_a716c_row11_col3,#T_a716c_row12_col2,#T_a716c_row12_col3,#T_a716c_row13_col3,#T_a716c_row14_col3,#T_a716c_row15_col3,#T_a716c_row16_col3,#T_a716c_row17_col3{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_a716c_row1_col2{
#             background-color:  #aad3aa;
#             color:  #000000;
#         }#T_a716c_row2_col2{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_a716c_row4_col2{
# ...

# %%
px.glimpse(df)
# Out:
# Rows: 21626
# Columns: 18
#                             dtype  \
# incident_key                int64
# occur_date                 object
# occur_time                 object
# boro                     category
# precinct                    int64
# jurisdiction_code        category
# statistical_murder_flag      bool
# perp_age_group           category
# perp_sex                 category
# perp_race                category
# vic_age_group            category
# vic_sex                  category
# vic_race                 category
# x_coord_cd                 object
# y_coord_cd                 object
# latitude                  float64
# longitude                 float64
# lon_lat                    object
#
#                                                              unique values
# incident_key             [201575314, 205748546, 193118596, 204192600, 2...
# occur_date               [08/23/2019, 11/27/2019, 02/02/2019, 10/24/201...
# ...

# %%
px.missing_values(df)
# Out:
# Your selected dataframe has 19 columns.
# There are 5 columns that have missing values.
# <style  type="text/css" >
# #T_f0036_row0_col0{
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }#T_f0036_row1_col0{
#             background-color:  #f17b1a;
#             color:  #000000;
#         }#T_f0036_row2_col0,#T_f0036_row3_col0{
#             background-color:  #f17c1a;
#             color:  #000000;
#         }#T_f0036_row4_col0{
#             background-color:  #ffffe5;
#             color:  #000000;
#         }</style><table id="T_f0036_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Missing Values</th>        <th class="col_heading level0 col1" >% of Total Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0036_level0_row0" class="row_heading level0 row0" >LOCATION_DESC</th>
# ...

# %%
px.any_value(df, "12/01/2019")
# Out:
#      INCIDENT_KEY  OCCUR_DATE OCCUR_TIME           BORO  PRECINCT  \
# 425     205862274  12/01/2019   21:10:00       BROOKLYN        81
# 719     205862275  12/01/2019   01:07:00         QUEENS       114
# 760     205862271  12/01/2019   03:32:00  STATEN ISLAND       123
# 915     205862276  12/01/2019   22:10:00       BROOKLYN        81
#
#      JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 425                0.0                        NaN                    False
# 719                0.0                        NaN                    False
# 760                0.0                        NaN                    False
# 915                2.0  MULTI DWELL - PUBLIC HOUS                    False
#
#     PERP_AGE_GROUP PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX VIC_RACE  \
# 425          25-44        M     BLACK         25-44       M    BLACK
# 719            NaN      NaN       NaN         18-24       M    BLACK
# ...

# %%
px.help()
# Out:
# ======= PandasExplorer 1.01 ========
#
# Función              Parámetros                Info
# ---------------------------------------------------------------------------------
# check_df             dataframe                 Analiza un dataframe
# col_rename           dataframe                 Cambia el nombre de las columnas

# %%
px.plot_numcat(df, "BORO", "VIC_AGE_GROUP")

# %%
px.correlation(df)

# %%
df = px.clean_nan(df, 0.4)
# Out:
# Se eliminaron las sig. columnas:
# -------------------------
# LOCATION_DESC

# %%
df = px.col_rename(df)

# %%
df.columns
# Out:
# Index(['incident_key', 'occur_date', 'occur_time', 'boro', 'precinct',
#        'jurisdiction_code', 'statistical_murder_flag', 'perp_age_group',
#        'perp_sex', 'perp_race', 'vic_age_group', 'vic_sex', 'vic_race',
#        'x_coord_cd', 'y_coord_cd', 'latitude', 'longitude', 'lon_lat'],
#       dtype='object')

# %%
px.check_cat(df)
# Out:
# Las columnas recomendadas:
# --------------------------
# boro(5)
# jurisdiction_code(4)
# perp_age_group(10)
# perp_sex(4)
# perp_race(8)
# vic_age_group(6)
# vic_sex(3)
# vic_race(7)

# %%
df = px.make_cat(df)
# Out:
# Las columnas convertidas:
# -------------------------
# boro (5)
# jurisdiction_code (4)
# perp_age_group (9)
# perp_sex (4)
# perp_race (7)
# vic_age_group (6)
# vic_sex (3)
# vic_race (7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df_num, df_cat = px.split_values(df)

# %%
px.grid_plot(df)
# Out:
#  guarde un momento...

# %%
log_vals = np.random.randint(3, 12)
outer_fence_le_l = 4
outer_fence_ue_l = 6

# %%
np.where((log_vals <= outer_fence_le_l) 
         | (log_vals >= outer_fence_ue_l)
         , True
         , False
)
# Out:
# array(True)

# %%
px.outliers(df)
# Out:
# === Grubbs' test ===
# fat
# fiber
# carbo
# potass
# weight
# rating
#
#  === Tukey's method  ===
# calories
#     [160, 70, 140, 50, 150]
#     [160, 50, 150, 70]
# protein
#     [6]
#     []
# fiber
#     [9.0, 10.0, 14.0]
#     []
# vitamins
#     [0, 25, 100]
#     [0, 25, 100]
# weight
#     [0.5, 1.0, 1.5, 1.3, 1.33, 1.25, 0.83]
#     [0.5, 1.0, 1.5, 1.3, 1.33, 1.25, 0.83]
#
#  === Z-Score method  ===
# protein
#     [6]
# fat
#     [5]
# fiber
#     [10.0, 14.0]
# carbo
#     [-1.0]
# potass
#     [320, 330]
# vitamins
#     [100]
# weight
#     [0.5, 1.5]
# rating
#     [93.7]
# ['calories',
#  'carbo',
#  'fat',
#  'vitamins',
#  'potass',
#  'fiber',
#  'rating',
#  'weight',
#  'protein']

# %%
df.JURISDICTION_CODE.unique()
# Out:
# array([ 0.,  2.,  1., nan])

# %%
px.outliers_graph(df)

# %%
log_vals = np.log(np.abs(dm) + 1)

# %%
log_vals
# Out:
# array([0.69314718, 1.38629436, 1.60943791, 0.        , 0.28517894,
#        1.38629436, 3.8286414 , 0.        ])

# %%
q1_log = np.quantile(df["fat"], 0.75)

# %%
df.columns
# Out:
# Index(['INCIDENT_KEY', 'OCCUR_DATE', 'OCCUR_TIME', 'BORO', 'PRECINCT',
#        'JURISDICTION_CODE', 'LOCATION_DESC', 'STATISTICAL_MURDER_FLAG',
#        'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'VIC_AGE_GROUP', 'VIC_SEX',
#        'VIC_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lon_Lat'],
#       dtype='object')

# %%
np.log10(3444443)
# Out:
# 6.537119002271417
