# %%
import pexplorer as px
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"H:\BOOK\CSV\NYPD_Shooting_Incident_Data__Historic_.csv")

# %%
px.correlation(df)
# Out:
# <style  type="text/css" >
# #T_34435_row0_col0,#T_34435_row1_col1,#T_34435_row2_col2,#T_34435_row3_col3,#T_34435_row4_col4,#T_34435_row5_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_34435_row0_col1{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_34435_row0_col2{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_34435_row0_col3,#T_34435_row4_col3{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_34435_row0_col4{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_34435_row0_col5{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_34435_row1_col0{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_34435_row1_col2,#T_34435_row4_col0{
#             background-color:  #fcf4fa;
#             color:  #000000;
# ...

# %%
px.check_df(df)
# Out:
# <style  type="text/css" >
# #T_32e24_row0_col2,#T_32e24_row6_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_32e24_row0_col3,#T_32e24_row1_col3,#T_32e24_row2_col3,#T_32e24_row3_col2,#T_32e24_row3_col3,#T_32e24_row4_col3,#T_32e24_row5_col2,#T_32e24_row5_col3,#T_32e24_row6_col2,#T_32e24_row7_col2,#T_32e24_row7_col3,#T_32e24_row8_col2,#T_32e24_row9_col2,#T_32e24_row10_col2,#T_32e24_row11_col2,#T_32e24_row11_col3,#T_32e24_row12_col2,#T_32e24_row12_col3,#T_32e24_row13_col2,#T_32e24_row13_col3,#T_32e24_row14_col3,#T_32e24_row15_col3,#T_32e24_row16_col3,#T_32e24_row17_col3,#T_32e24_row18_col3{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_32e24_row1_col2{
#             background-color:  #aad3aa;
#             color:  #000000;
#         }#T_32e24_row2_col2{
#             background-color:  #d5e9d5;
#             color:  #000000;
#         }#T_32e24_row4_col2{
#             background-color:  #eaf2ea;
# ...

# %%
df = px.col_rename(df)

# %%
df.columns
# Out:
# Index(['incident_key', 'occur_date', 'occur_time', 'boro', 'precinct',
#        'jurisdiction_code', 'location_desc', 'statistical_murder_flag',
#        'perp_age_group', 'perp_sex', 'perp_race', 'vic_age_group', 'vic_sex',
#        'vic_race', 'x_coord_cd', 'y_coord_cd', 'latitude', 'longitude',
#        'lon_lat'],
#       dtype='object')

# %%
px.check_cat(df)
# Out:
# Las columnas recomendadas:
# --------------------------
# boro(5)
# jurisdiction_code(4)
# location_desc(40)
# perp_age_group(10)
# perp_sex(4)
# perp_race(8)
# vic_age_group(6)
# vic_sex(3)
# vic_race(7)

# %%
df = px.make_cat(df)
# Out:
# Una columna ya es CATEGORICAL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21626 entries, 0 to 21625
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   incident_key             21626 non-null  int64
#  1   occur_date               21626 non-null  object
#  2   occur_time               21626 non-null  object
#  3   boro                     21626 non-null  object
#  4   precinct                 21626 non-null  int64
#  5   jurisdiction_code        21624 non-null  float64
#  6   location_desc            9265 non-null   object
#  7   statistical_murder_flag  21626 non-null  bool
#  8   perp_age_group           14321 non-null  object
#  9   perp_sex                 14355 non-null  object
#  10  perp_race                14355 non-null  object
#  11  vic_age_group            21626 non-null  object
#  12  vic_sex                  21626 non-null  object
#  13  vic_race                 21626 non-null  object
# ...
